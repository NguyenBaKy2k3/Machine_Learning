# %% [markdown]
# # Water

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# To scale the data using z-score //Để chia tỷ lệ dữ liệu bằng z-score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Metrics to evaluate the model // Số liệu để đánh giá mô hình
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# For tuning the model // Để điều chỉnh mô hình
from sklearn.model_selection import GridSearchCV

# To ignore warnings // Để bỏ qua cảnh báo
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the dataset
df = pd.read_csv('water.csv')
print(df)

# %%
# check few observations
df.head()

# %%
# Check the variable types
df.info()

# %%
# Check percent of missing
(df.isnull().sum() / df.shape[0])*100

# %%
# Checking for duplicate values
df.duplicated().sum()

# %%
# Creating numerical columns
num_cols = ['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine', 
            'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead', 
            'nitrates', 'nitrites', 'mercury', 'perchlorate','radium', 'selenium', 
            'silver', 'uranium', 'issafe']

# %%
## Univariate analysis of numerical columns

# Checking summary statistics
df[num_cols].describe().T

# %%
# Creating histograms
df[num_cols].hist(figsize = (14, 14))
plt.show()

# %%
# The mean of numerical variables grouped by attrition
df.groupby([''])[num_cols].mean()

# %%
# The median of numerical variables grouped by attrition
df.groupby([''])[num_cols].median()

# %%
# Plotting the correlation between numerical variables
plt.figure(figsize = (15, 8))
sns.heatmap(df[num_cols].corr(), annot = True, fmt = '0.2f', cmap = 'YlGnBu');
